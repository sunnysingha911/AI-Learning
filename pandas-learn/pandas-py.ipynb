# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
sales = pd.Series([5,3,2,7,3])

# %%
sales
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
sales[1]
# Out:
# np.int64(3)

# %%
sales[0:2]
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
sales.values
# Out:
# array([2, 3, 5])

# %%
sales.dtype
# Out:
# dtype('int64')

# %%
sales.head()
# Out:
# 0    2
# 1    3
# 2    5
# dtype: int64

# %%
sales.sort_values()
# Out:
# 2    2
# 1    3
# 4    3
# 0    5
# 3    7
# dtype: int64

# %%
sales.count()
# Out:
# np.int64(5)

# %%
sales.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# dtype: bool

# %%
sales_missing = pd.Series([2,None, 5])

# %%
sales_missing.fillna(0)
# Out:
# 0    2.0
# 1    0.0
# 2    5.0
# dtype: float64

# %%
si = pd.Series(data=[100, 200,300, 400, 500, ], index=list('abcde'))

# %%
si
# Out:
# a    100
# b    200
# c    300
# d    400
# e    500
# dtype: int64

# %% [markdown]
# Pandas Data frame

# %%
data = pd.DataFrame({
    'Name': ['Anna', 'Ben'],
    'Lemonades': [2,3]
})

# %%
data
# Out:
#    Name  Lemonades
# 0  Anna          2
# 1   Ben          3

# %%
s1 = pd.Series(data=[1,2,3,4,5])
s2 = pd.Series(data=[10,20,30,40,50])

# %%
data = pd.DataFrame({
    'C1': s1,
    'C2': s2
})

# %%
data
# Out:
#    C1  C2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data.shape
# Out:
# (5, 2)

# %% [markdown]
# Accessing Data

# %%
data.dtypes
data.iloc[3]
# Out:
# C1     4
# C2    40
# Name: 3, dtype: int64

# %%
data.loc[1,'C1']
# Out:
# np.int64(2)

# %%
data.iloc[1,1]
# Out:
# np.int64(20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C1      5 non-null      int64
#  1   C2      5 non-null      int64
# dtypes: int64(2)
# memory usage: 212.0 bytes

# %%
data.describe()
# Out:
#              C1         C2
# count  5.000000   5.000000
# mean   3.000000  30.000000
# std    1.581139  15.811388
# min    1.000000  10.000000
# 25%    2.000000  20.000000
# 50%    3.000000  30.000000
# 75%    4.000000  40.000000
# max    5.000000  50.000000

# %% [markdown]
# Filtering

# %%
data[data['C1'] != 2]
# Out:
#    C1  C2
# 0   1  10
# 2   3  30
# 3   4  40
# 4   5  50

# %% [markdown]
# Adding, Updating, Deleting

# %%
data['tips'] = [1,2,3,4,5]

# %%
data
# Out:
#    C1  C2  tips
# 0   1  10     1
# 1   2  20     2
# 2   3  30     3
# 3   4  40     4
# 4   5  50     5

# %%
# del data['tips']
# data
# Out:
#    C1  C2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data  = data.drop(columns=['tips'])
data
# Out:
#    C1  C2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data.loc[data['C1'] == 2]=10
data
# Out:
#    C1  C2
# 0   1  10
# 1  10  10
# 2   3  30
# 3   4  40
# 4   5  50

# %%
data.rename(columns={'C1': 'Column1'}, inplace=True)
data
# Out:
#    Column1  C2
# 0        1  10
# 1       10  10
# 2        3  30
# 3        4  40
# 4        5  50

# %% [markdown]
# Indexing and selecting

# %%
data.set_index("Column1", inplace=True)
data
# Out:
#          C2
# Column1
# 1        10
# 10       10
# 3        30
# 4        40
# 5        50

# %%
data.reset_index(inplace=True)
data
# Out:
#    index  Column1  C2
# 0      0        1  10
# 1      1       10  10
# 2      2        3  30
# 3      3        4  40
# 4      4        5  50

# %% [markdown]
# Multi Data Index

# %%
multi_data = pd.DataFrame({
    'Park': ['A','A','B','B'],
    'Name': ['Anna','Ben','Chris', 'Daisy'],
    'Lemonades': [2,3,4,5]
}).set_index(['Park', 'Name'])

# %%
multi_data
# Out:
#             Lemonades
# Park Name
# A    Anna           2
#      Ben            3
# B    Chris          4
#      Daisy          5

# %%
multi_data.query('Lemonades > 3')
# Out:
#             Lemonades
# Park Name
# B    Chris          4
#      Daisy          5

# %%
multi_data.to_csv("lemonade_sales.csv")

# %%
data1 = pd.read_csv("lemonade_sales.csv")
data1
# Out:
#   Park   Name  Lemonades
# 0    A   Anna          2
# 1    A    Ben          3
# 2    B  Chris          4
# 3    B  Daisy          5

# %%
import numpy as np

dictt = {
    'x':[1,2,3],
    'y':np.array([10,20, 30]),
    'z': 50
}

dictt
# Out:
# {'x': [1, 2, 3], 'y': array([10, 20, 30]), 'z': 50}

# %%
pd.DataFrame(dictt)
# Out:
#    x   y   z
# 0  1  10  50
# 1  2  20  50
# 2  3  30  50

# %%
listt  = [[1,2,100],[2,4,100],[3,8,100]]
pd.DataFrame(listt, columns=['x','y', 'z'])
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
np_arr = np.array([[1,2,100],[2,4,100],[3,8,100]])
pd.DataFrame(np_arr,columns=['a','b','c'])
# Out:
#    a  b    c
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %% [markdown]
# Data cleaning and pre-processing

# %%
sales_missing_2 = pd.Series([2,None, 5])
sales_missing_2.fillna(5)
# Out:
# 0    2.0
# 1    5.0
# 2    5.0
# dtype: float64

# %%
sales_missing_2.mean()
# Out:
# np.float64(3.5)
