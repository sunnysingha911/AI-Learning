# %%
import os 
from dotenv import load_dotenv
from openai import OpenAI

# %%
os.environ.items()
load_dotenv(dotenv_path="./.env")
# Out:
# True

# %%
assert os.getenv("OPENAI_API_KEY") is not None, "API key not loaded"

# %%
api_key = os.getenv("OPENAI_API_KEY")

# %%
client = OpenAI()

# %%
completion = client.chat.completions.create(model="gpt-3.5-turbo", 
                                            messages=[
                                                {
                                                    "role":'system',
                                                    'content':'''You are Marv a chatbot that reluctantly answers 
                                                     question with sarcastic response '''
                                                 },
                                                {
                                                    'role':'user',
                                                    'content':'''I have recently bought a dog can you suggest some dog names?'''
                                                }])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 completion = client.chat.completions.create(model="gpt-3.5-turbo",
#       2                                             messages=[
#       3                                                 {
#       4                                                     "role":'system',
#       5                                                     'content':'''You are Marv a chatbot that reluctantly answers
#       6                                                      question with sarcastic response '''
#       7                                                  },
#       8                                                 {
#       9                                                     'role':'user',
# ...
